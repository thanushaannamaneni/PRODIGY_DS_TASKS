# %% [markdown]
# # Welcome to Colab!

# %%
import pandas as pd
import matplotlib.pyplot as plt
from textblob import TextBlob

# %%
data = {
    "text": [
        "I love this product!",
        "This service is terrible",
        "Amazing experience, very happy",
        "Not satisfied with the quality",
        "It's okay, nothing special",
        "Excellent performance and fast delivery",
        "Worst purchase ever",
        "I am very happy with this brand",
        "Bad customer support",
        "Great value for money"
    ]
}

df = pd.DataFrame(data)
df
# Out:
#                                       text
# 0                     I love this product!
# 1                 This service is terrible
# 2           Amazing experience, very happy
# 3           Not satisfied with the quality
# 4               It's okay, nothing special
# 5  Excellent performance and fast delivery
# 6                      Worst purchase ever
# 7          I am very happy with this brand
# 8                     Bad customer support
# 9                    Great value for money

# %%
def get_sentiment(text):
    polarity = TextBlob(text).sentiment.polarity

    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

df['Sentiment'] = df['text'].apply(get_sentiment)
df
# Out:
#                                       text Sentiment
# 0                     I love this product!  Positive
# 1                 This service is terrible  Negative
# 2           Amazing experience, very happy  Positive
# 3           Not satisfied with the quality  Negative
# 4               It's okay, nothing special  Positive
# 5  Excellent performance and fast delivery  Positive
# 6                      Worst purchase ever  Negative
# 7          I am very happy with this brand  Positive
# 8                     Bad customer support  Negative
# 9                    Great value for money  Positive

# %%
df['Sentiment'].value_counts()
# Out:
# Sentiment
# Positive    6
# Negative    4
# Name: count, dtype: int64

# %%
df['Sentiment'].value_counts().plot(kind='bar')

plt.title("Sentiment Distribution")
plt.xlabel("Sentiment")
plt.ylabel("Count")

plt.show()

# %%
df['Sentiment'].value_counts().plot(kind='pie', autopct='%1.1f%%')

plt.title("Sentiment Percentage")
plt.ylabel("")
plt.show()
